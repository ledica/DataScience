# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

plt.style.use('bmh')

# %%
df = pd.read_csv('fire.txt',sep=' ', error_bad_lines=False)
df.head()
# Out:
#          data  mes    lat    lon  cbiol_10  cbiol_11  cbiol_12   cbiol_1  \
# 0  2100-01-01    1 -17.25 -44.75  0.000633  0.268900  0.000740  0.000400
# 1  2100-01-01    1 -17.25 -44.25  0.000500  0.001090  0.000710  0.001498
# 2  2100-01-01    1 -17.25 -43.75  0.000635  0.002051  0.000899  0.001389
# 3  2100-01-01    1 -17.25 -43.25  0.001032  0.004521  0.001467  0.001388
# 4  2100-01-01    1 -17.75 -44.75  0.000600  0.166074  0.000720  0.000400
#
#     cbiol_2  cbiol_3  ...  frac_6  frac_7  frac_8    frac_9     rain  \
# 0  0.000400        0  ...       0       0       0  0.002343  7.80001
# 1  0.154037        0  ...       0       0       0  0.192936  7.50001
# 2  0.139408        0  ...       0       0       0  0.154704  7.00001
# 3  0.127355        0  ...       0       0       0  0.109585  6.40001
# 4  0.000400        0  ...       0       0       0  0.003554  8.30001
#
#     totalit    totbio       ua      wsoi    modis
# 0  0.021663  0.284048  2.89223  0.569957  2.00000
# 1  0.404718  6.097360  3.07320  0.712448  2.00000
# 2  0.387955  5.699300  3.03958  0.721108  2.50000
# 3  0.330039  4.890060  3.21707  0.740557  3.42857
# 4  0.013739  0.180828  2.91942  0.594762  1.66667
#
# [5 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1596 entries, 0 to 1595
# Data columns (total 46 columns):
# data        1596 non-null object
# mes         1596 non-null int64
# lat         1596 non-null float64
# lon         1596 non-null float64
# cbiol_10    1596 non-null float64
# cbiol_11    1596 non-null float64
# cbiol_12    1596 non-null float64
# cbiol_1     1596 non-null float64
# cbiol_2     1596 non-null float64
# cbiol_3     1596 non-null int64
# cbiol_4     1596 non-null int64
# cbiol_5     1596 non-null int64
# cbiol_6     1596 non-null int64
# cbiol_7     1596 non-null int64
# cbiol_8     1596 non-null int64
# cbiol_9     1596 non-null float64
# cbiow_10    1596 non-null float64
# cbiow_11    1596 non-null int64
# cbiow_12    1596 non-null int64
# cbiow_1     1596 non-null float64
# cbiow_2     1596 non-null float64
# cbiow_3     1596 non-null int64
# cbiow_4     1596 non-null int64
# cbiow_5     1596 non-null int64
# cbiow_6     1596 non-null int64
# cbiow_7     1596 non-null int64
# cbiow_8     1596 non-null int64
# cbiow_9     1596 non-null float64
# frac_10     1596 non-null float64
# frac_11     1596 non-null float64
# frac_12     1596 non-null float64
# frac_1      1596 non-null float64
# frac_2      1596 non-null float64
# frac_3      1596 non-null int64
# frac_4      1596 non-null int64
# frac_5      1596 non-null int64
# frac_6      1596 non-null int64
# frac_7      1596 non-null int64
# frac_8      1596 non-null int64
# frac_9      1596 non-null float64
# rain        1596 non-null float64
# totalit     1596 non-null float64
# totbio      1596 non-null float64
# ua          1596 non-null float64
# wsoi        1596 non-null float64
# modis       1596 non-null float64
# dtypes: float64(24), int64(21), object(1)
# memory usage: 567.4+ KB

# %%
print(df['modis'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(df['modis'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    1596.000000
# mean       11.266036
# std        15.453532
# min         1.000000
# 25%         2.285710
# 50%         3.692310
# 75%        14.176500
# max        88.529400
# Name: modis, dtype: float64

# %%
print(df['rain'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(df['rain'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    1596.000000
# mean        3.437596
# std         2.981985
# min         0.100000
# 25%         0.500000
# 50%         3.600000
# 75%         6.400010
# max         9.200010
# Name: rain, dtype: float64

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
df_num_corr = df_num.corr()['modis'][:-1] # -1 because the latest row is SalePrice
golden_features_list = df_num_corr[abs(df_num_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with Fire:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 1 strongly correlated values with SalePrice:
# wsoi   -0.554914
# Name: modis, dtype: float64
